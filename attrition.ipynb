# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers


#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']].set_index(attrition_df.index)
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# get a list of all columns
attrition_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Create a list of at least 10 column names to use as X data
columns = ['Age', 'BusinessTravel', 'DistanceFromHome',
       'Education', 'HourlyRate', 'JobLevel', 'JobSatisfaction', 'PerformanceRating', 'WorkLifeBalance',
       'YearsAtCompany']


# Create X_df using your selected columns
X_df = attrition_df[columns]
X_df.head()
# Out:
#    Age     BusinessTravel  DistanceFromHome  Education  HourlyRate  JobLevel  \
# 0   41      Travel_Rarely                 1          2          94         2
# 1   49  Travel_Frequently                 8          1          61         2
# 2   37      Travel_Rarely                 2          2          92         1
# 3   33  Travel_Frequently                 3          4          56         1
# 4   27      Travel_Rarely                 2          1          40         1
#
#    JobSatisfaction  PerformanceRating  WorkLifeBalance  YearsAtCompany
# 0                4                  3                1               6
# 1                2                  4                3              10
# 2                3                  3                3               0
# 3                3                  3                3               8
# 4                2                  3                3               2

# %%
# Show the data types for X_df
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                1470 non-null   int64
#  1   BusinessTravel     1470 non-null   object
#  2   DistanceFromHome   1470 non-null   int64
#  3   Education          1470 non-null   int64
#  4   HourlyRate         1470 non-null   int64
#  5   JobLevel           1470 non-null   int64
#  6   JobSatisfaction    1470 non-null   int64
#  7   PerformanceRating  1470 non-null   int64
#  8   WorkLifeBalance    1470 non-null   int64
#  9   YearsAtCompany     1470 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 115.0+ KB

# %%
# Split the data into training and testing sets
# Split data into X and two separate y variables
X = X_df
y_dept = pd.DataFrame(y_df["Department"], index=X_df.index)
y_att = pd.DataFrame(y_df["Attrition"], index=X_df.index)

# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_dept_train, y_dept_test, y_att_train, y_att_test = train_test_split(X, y_dept, y_att, test_size= 0.2, random_state=1)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_df["BusinessTravel"].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
# Explore y data
print(f"Department Classes: {y_dept.value_counts()}")
print(f"Attrition Classes: {y_att.value_counts()}")
# Out:
# Department Classes: Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# Attrition Classes: Attrition
# No           1233
# Yes           237
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
# Preprocess "BusinessTravel" column (one-hot encoding for multiclass)

# initialize the encoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Fit the encoder on the training set and transform training and testing
X_train_encoded = encoder.fit_transform(X_train[['BusinessTravel']])
X_test_encoded = encoder.transform(X_test[['BusinessTravel']])

# get column names out
encoded_feature_names = encoder.get_feature_names_out(['BusinessTravel'])

# convert to df
X_train_processed = pd.DataFrame(X_train_encoded, columns=encoded_feature_names).reset_index(drop=True)
X_test_processed = pd.DataFrame(X_test_encoded, columns=encoded_feature_names).reset_index(drop=True)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
# Out:
# (1176, 3)
# (294, 3)

# %%
# Drop the original BT column from X_train and X_test
X_train_drop = X_train.drop(['BusinessTravel'], axis=1).reset_index(drop=True)
X_test_drop = X_test.drop(['BusinessTravel'], axis=1).reset_index(drop=True)
print(X_train_drop.shape)
print(X_test_drop.shape)
# Out:
# (1176, 9)
# (294, 9)

# %%
# Check for null values in the original and processed DataFrames
print("Null values in X_train_drop:\n", X_train_drop.isnull().sum())
print("Null values in X_train_processed:\n", X_train_processed.isnull().sum())
print("Null values in X_test_drop:\n", X_test_drop.isnull().sum())
print("Null values in X_test_processed:\n", X_test_processed.isnull().sum())
# Out:
# Null values in X_train_drop:
#  Age                  0
# DistanceFromHome     0
# Education            0
# HourlyRate           0
# JobLevel             0
# JobSatisfaction      0
# PerformanceRating    0
# WorkLifeBalance      0
# YearsAtCompany       0
# dtype: int64
# Null values in X_train_processed:
#  BusinessTravel_Non-Travel           0
# BusinessTravel_Travel_Frequently    0
# BusinessTravel_Travel_Rarely        0
# dtype: int64
# Null values in X_test_drop:
#  Age                  0
# DistanceFromHome     0
# Education            0
# HourlyRate           0
# JobLevel             0
# JobSatisfaction      0
# PerformanceRating    0
# WorkLifeBalance      0
# YearsAtCompany       0
# dtype: int64
# Null values in X_test_processed:
#  BusinessTravel_Non-Travel           0
# BusinessTravel_Travel_Frequently    0
# BusinessTravel_Travel_Rarely        0
# dtype: int64

# %%
print("X_train_drop index:", X_train_drop.index)
print("X_train_processed index:", X_train_processed.index)
# Out:
# X_train_drop index: RangeIndex(start=0, stop=1176, step=1)
# X_train_processed index: RangeIndex(start=0, stop=1176, step=1)

# %%
X_train_concat = pd.concat([X_train_drop, X_train_processed], axis=1)
X_test_concat = pd.concat([X_test_drop, X_test_processed], axis=1)
print(X_train_concat.shape)
print(X_test_concat.shape)
# Out:
# (1176, 12)
# (294, 12)

# %%
# Create a OneHotEncoder for the Department column
encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
# Create two new variables by applying the encoder
# to the training and testing data
y_dept_train_encoded = encoder.fit_transform(y_dept_train[["Department"]])
y_dept_test_encoded = encoder.transform(y_dept_test[["Department"]])

# %%
# Create a OneHotEncoder for the Attrition column
encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
# Create two new variables by applying the encoder
# to the training and testing data
y_att_train_encoded = encoder.fit_transform(y_att_train[["Attrition"]])
y_att_test_encoded = encoder.transform(y_att_test[["Attrition"]])

# %%
print({y_att_train.shape})
print({y_att_test.shape})
print({X_train.shape})
# Out:
# {(1176, 1)}
# {(294, 1)}
# {(1176, 10)}

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
columns = X_train.columns
print(len(columns))

# Create the input layer
input_layer = layers.Input(shape=(12,), name="input_features")

# Shared hidden layers
shared_layer_1 = layers.Dense(128, activation='relu', name = "input_layer")(input_layer)
shared_layer_2 = layers.Dense(64, activation='relu', name = "shared_layer_1")(shared_layer_1)
# Out:
# 10

# %%
# Create a branch for Department
# with a hidden layer and an output layer
# multiclass:
# Create the hidden layer
department_layer = layers.Dense(32, activation='relu', name = "department_hidden_layer")(shared_layer_2)

# Create the output layer
# Branch for quality prediction
department_output = layers.Dense(3, activation='softmax', name='department_output')(department_layer)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
attrition_layer = layers.Dense(32, activation='relu', name = "attrition_hidden_layer")(shared_layer_2)

# Create the output layer

attrition_output = layers.Dense(2, activation='sigmoid', name='attrition_output')(attrition_layer)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[
    department_output,
    attrition_output,
])


# Compile the model
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy',
                    'attrition_output': 'binary_crossentropy'},
              metrics={'department_output': 'accuracy',
                       'attrition_output': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_features            │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer (Dense)       │ (None, 128)            │          1,664 │ input_features[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ shared_layer_1 (Dense)    │ (None, 64)             │          8,256 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department_hidden_layer   │ (None, 32)             │          2,080 │ shared_layer_1[0][0]   │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition_hidden_layer    │ (None, 32)             │          2,080 │ shared_layer_1[0][0]   │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department_output (Dense) │ (None, 3)              │             99 │ department_hidden_lay… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition_output (Dense)  │ (None, 2)              │             66 │ attrition_hidden_laye… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 14,245 (55.64 KB)
#  Trainable params: 14,245 (55.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(
    X_train_concat,
    {'department_output': y_dept_train_encoded, 'attrition_output': y_att_train_encoded},
    epochs=100,
    batch_size=35,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - attrition_output_accuracy: 0.8377 - department_output_accuracy: 0.4768 - loss: 3.1089 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6525 - val_loss: 1.2593
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8523 - department_output_accuracy: 0.6446 - loss: 1.2140 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2578
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8520 - department_output_accuracy: 0.6598 - loss: 1.1898 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6059 - val_loss: 1.2677
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8722 - department_output_accuracy: 0.6498 - loss: 1.1662 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2562
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8768 - department_output_accuracy: 0.6683 - loss: 1.1409 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2861
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8254 - department_output_accuracy: 0.6640 - loss: 1.2331 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6314 - val_loss: 1.3509
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8265 - department_output_accuracy: 0.6527 - loss: 1.2325 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6102 - val_loss: 1.3234
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8518 - department_output_accuracy: 0.6733 - loss: 1.1913 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2930
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8558 - department_output_accuracy: 0.6277 - loss: 1.2181 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6271 - val_loss: 1.3190
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8394 - department_output_accuracy: 0.6127 - loss: 1.2161 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.3242
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8485 - department_output_accuracy: 0.6159 - loss: 1.2842 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.3736
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8443 - department_output_accuracy: 0.6178 - loss: 1.2330 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.3158
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8614 - department_output_accuracy: 0.6686 - loss: 1.1792 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2920
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8583 - department_output_accuracy: 0.6677 - loss: 1.1276 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.5932 - val_loss: 1.2798
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8514 - department_output_accuracy: 0.6675 - loss: 1.1509 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6314 - val_loss: 1.2777
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8537 - department_output_accuracy: 0.6509 - loss: 1.2269 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2611
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8698 - department_output_accuracy: 0.6493 - loss: 1.1139 - val_attrition_output_accuracy: 0.8263 - val_department_output_accuracy: 0.6398 - val_loss: 1.2695
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8632 - department_output_accuracy: 0.6524 - loss: 1.1629 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6356 - val_loss: 1.2712
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8522 - department_output_accuracy: 0.6911 - loss: 1.1310 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2829
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8536 - department_output_accuracy: 0.6525 - loss: 1.1619 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6271 - val_loss: 1.2666
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8532 - department_output_accuracy: 0.6621 - loss: 1.1515 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2655
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8642 - department_output_accuracy: 0.6557 - loss: 1.1433 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6271 - val_loss: 1.2749
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8521 - department_output_accuracy: 0.6478 - loss: 1.1740 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6441 - val_loss: 1.2684
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8438 - department_output_accuracy: 0.6482 - loss: 1.1952 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6356 - val_loss: 1.2763
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8621 - department_output_accuracy: 0.6483 - loss: 1.1568 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6568 - val_loss: 1.2892
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8649 - department_output_accuracy: 0.6887 - loss: 1.1186 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.5678 - val_loss: 1.3196
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8625 - department_output_accuracy: 0.6281 - loss: 1.1538 - val_attrition_output_accuracy: 0.8432 - val_department_output_accuracy: 0.6398 - val_loss: 1.2611
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8582 - department_output_accuracy: 0.6889 - loss: 1.0878 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6483 - val_loss: 1.2529
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8616 - department_output_accuracy: 0.6656 - loss: 1.1065 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6356 - val_loss: 1.2529
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8704 - department_output_accuracy: 0.6927 - loss: 1.1065 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6356 - val_loss: 1.2579
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8390 - department_output_accuracy: 0.6458 - loss: 1.1816 - val_attrition_output_accuracy: 0.8432 - val_department_output_accuracy: 0.6525 - val_loss: 1.2446
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8566 - department_output_accuracy: 0.6774 - loss: 1.1149 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6314 - val_loss: 1.2885
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8644 - department_output_accuracy: 0.6519 - loss: 1.1548 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6356 - val_loss: 1.3083
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8535 - department_output_accuracy: 0.6757 - loss: 1.1432 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6229 - val_loss: 1.3062
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8691 - department_output_accuracy: 0.6796 - loss: 1.1123 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6441 - val_loss: 1.2675
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8641 - department_output_accuracy: 0.6593 - loss: 1.1179 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.3038
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8592 - department_output_accuracy: 0.6689 - loss: 1.1551 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6356 - val_loss: 1.3127
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8721 - department_output_accuracy: 0.6375 - loss: 1.0978 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2836
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8618 - department_output_accuracy: 0.6444 - loss: 1.1534 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.4081
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8415 - department_output_accuracy: 0.6628 - loss: 1.1873 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6271 - val_loss: 1.2760
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8631 - department_output_accuracy: 0.6665 - loss: 1.1063 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6314 - val_loss: 1.2825
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8598 - department_output_accuracy: 0.6419 - loss: 1.1168 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6314 - val_loss: 1.2982
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8565 - department_output_accuracy: 0.6982 - loss: 1.0840 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6271 - val_loss: 1.2748
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8577 - department_output_accuracy: 0.6519 - loss: 1.1147 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6356 - val_loss: 1.2548
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8564 - department_output_accuracy: 0.6794 - loss: 1.0589 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.3019
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8597 - department_output_accuracy: 0.6611 - loss: 1.1012 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6314 - val_loss: 1.2510
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8584 - department_output_accuracy: 0.6709 - loss: 1.0745 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6398 - val_loss: 1.2795
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8687 - department_output_accuracy: 0.6664 - loss: 1.0731 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2679
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8667 - department_output_accuracy: 0.6746 - loss: 1.1197 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6102 - val_loss: 1.3130
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8417 - department_output_accuracy: 0.6722 - loss: 1.1271 - val_attrition_output_accuracy: 0.8432 - val_department_output_accuracy: 0.6229 - val_loss: 1.2701
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8638 - department_output_accuracy: 0.6950 - loss: 1.0643 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6271 - val_loss: 1.2701
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8371 - department_output_accuracy: 0.6845 - loss: 1.1085 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6356 - val_loss: 1.3199
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8638 - department_output_accuracy: 0.6663 - loss: 1.1429 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6186 - val_loss: 1.2678
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8781 - department_output_accuracy: 0.6932 - loss: 1.0452 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2826
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8619 - department_output_accuracy: 0.6806 - loss: 1.0804 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6186 - val_loss: 1.2672
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8659 - department_output_accuracy: 0.6706 - loss: 1.0752 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6186 - val_loss: 1.2805
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8749 - department_output_accuracy: 0.6777 - loss: 1.0531 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6314 - val_loss: 1.2984
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8763 - department_output_accuracy: 0.6681 - loss: 1.0917 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6398 - val_loss: 1.2794
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8606 - department_output_accuracy: 0.6699 - loss: 1.1155 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.5847 - val_loss: 1.3137
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8479 - department_output_accuracy: 0.6688 - loss: 1.0857 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6314 - val_loss: 1.2805
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8770 - department_output_accuracy: 0.6779 - loss: 1.0297 - val_attrition_output_accuracy: 0.8263 - val_department_output_accuracy: 0.6017 - val_loss: 1.3053
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8529 - department_output_accuracy: 0.6636 - loss: 1.0976 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6441 - val_loss: 1.2704
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8779 - department_output_accuracy: 0.6948 - loss: 1.0055 - val_attrition_output_accuracy: 0.8093 - val_department_output_accuracy: 0.6186 - val_loss: 1.2882
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8617 - department_output_accuracy: 0.6649 - loss: 1.0576 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2944
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8557 - department_output_accuracy: 0.6957 - loss: 1.0447 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6314 - val_loss: 1.2524
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8734 - department_output_accuracy: 0.6916 - loss: 1.0098 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6229 - val_loss: 1.2603
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8648 - department_output_accuracy: 0.6743 - loss: 1.0944 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6271 - val_loss: 1.2678
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8650 - department_output_accuracy: 0.6729 - loss: 1.0497 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6314 - val_loss: 1.2652
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8572 - department_output_accuracy: 0.6656 - loss: 1.0787 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6398 - val_loss: 1.2629
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8493 - department_output_accuracy: 0.6811 - loss: 1.0764 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6398 - val_loss: 1.3022
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8733 - department_output_accuracy: 0.6595 - loss: 1.0561 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6398 - val_loss: 1.2737
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8734 - department_output_accuracy: 0.6818 - loss: 1.0556 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6314 - val_loss: 1.2836
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8550 - department_output_accuracy: 0.6831 - loss: 1.0570 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6017 - val_loss: 1.2685
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8817 - department_output_accuracy: 0.6860 - loss: 1.0254 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.2782
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8745 - department_output_accuracy: 0.6615 - loss: 1.0276 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6271 - val_loss: 1.2724
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8574 - department_output_accuracy: 0.6960 - loss: 1.0328 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6271 - val_loss: 1.2767
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8863 - department_output_accuracy: 0.6984 - loss: 0.9731 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6271 - val_loss: 1.2799
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8452 - department_output_accuracy: 0.6936 - loss: 1.0492 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6314 - val_loss: 1.3077
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8799 - department_output_accuracy: 0.6905 - loss: 1.0438 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6314 - val_loss: 1.2959
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8703 - department_output_accuracy: 0.6764 - loss: 1.0471 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6441 - val_loss: 1.3440
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8682 - department_output_accuracy: 0.6905 - loss: 1.0192 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6229 - val_loss: 1.2776
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8665 - department_output_accuracy: 0.6961 - loss: 1.0008 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6271 - val_loss: 1.2841
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8532 - department_output_accuracy: 0.6974 - loss: 1.0547 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6271 - val_loss: 1.3321
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8618 - department_output_accuracy: 0.6884 - loss: 1.0740 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.3656
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8464 - department_output_accuracy: 0.6991 - loss: 1.0637 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6229 - val_loss: 1.2890
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8722 - department_output_accuracy: 0.6740 - loss: 1.0231 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6356 - val_loss: 1.2745
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8478 - department_output_accuracy: 0.6910 - loss: 1.0530 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6441 - val_loss: 1.2702
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8675 - department_output_accuracy: 0.7026 - loss: 0.9923 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6314 - val_loss: 1.2727
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8799 - department_output_accuracy: 0.6707 - loss: 0.9992 - val_attrition_output_accuracy: 0.8475 - val_department_output_accuracy: 0.6483 - val_loss: 1.2849
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8471 - department_output_accuracy: 0.6834 - loss: 1.0220 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6356 - val_loss: 1.2975
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8539 - department_output_accuracy: 0.6827 - loss: 1.0491 - val_attrition_output_accuracy: 0.8432 - val_department_output_accuracy: 0.6186 - val_loss: 1.3063
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8831 - department_output_accuracy: 0.7331 - loss: 0.9862 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6271 - val_loss: 1.3112
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8433 - department_output_accuracy: 0.6884 - loss: 1.0359 - val_attrition_output_accuracy: 0.8390 - val_department_output_accuracy: 0.6229 - val_loss: 1.2711
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8727 - department_output_accuracy: 0.6898 - loss: 1.0183 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6356 - val_loss: 1.3158
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8693 - department_output_accuracy: 0.7022 - loss: 0.9898 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6314 - val_loss: 1.2824
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8617 - department_output_accuracy: 0.7057 - loss: 0.9802 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6229 - val_loss: 1.3094
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8570 - department_output_accuracy: 0.7156 - loss: 0.9929 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6398 - val_loss: 1.3053
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8496 - department_output_accuracy: 0.7128 - loss: 1.0036 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6271 - val_loss: 1.2928
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8825 - department_output_accuracy: 0.7249 - loss: 0.9242 - val_attrition_output_accuracy: 0.8347 - val_department_output_accuracy: 0.6144 - val_loss: 1.3340
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8600 - department_output_accuracy: 0.7038 - loss: 1.0144 - val_attrition_output_accuracy: 0.8305 - val_department_output_accuracy: 0.6314 - val_loss: 1.2832

# %%
# Evaluate the model with the testing data
# The evaluate function returns the following:
# [total_loss, department_loss, attrition_loss,
#  total_accuracy, department_accuracy, attrition_accuracy]
test_results = model.evaluate(X_test_concat, {'department_output': y_dept_test_encoded, 'attrition_output': y_att_test_encoded})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.7907 - department_output_accuracy: 0.6353 - loss: 1.3128
# [1.260595679283142, 0.8027210831642151, 0.6326530575752258]

# %%
# Display evaluation results
print(f"Department Accuracy: {test_results[2]} \nAttrition Accuracy: {test_results[1]}")
# Out:
# Department Accuracy: 0.6326530575752258
# Attrition Accuracy: 0.8027210831642151

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# Accuracy is probably not the best metric to use here, particularly for the Department target. Department is multi-class, and the data is unbalanced with the majority falling into Research & Development. Accuracy is a better metric for Attrition because it is a simpler, binary classification of Yes or No. Even this classification might warrant a different metric because ethe Attrition data is so unbalanced (1233 No vs. 237 Yes).
#
#
# 2. What activation functions did you choose for your output layers, and why?
#
# For the Department output layer, I used the softmax activation function because this target was multi-classification, and the output would be one class rather than a mixed or hybrid classification. For the Activation output layer, I used sigmoid because it was a binary classification target.
#
# 3. Can you name a few ways that this model might be improved?
#
# There are a few things I would try in order to improve the model which has high loss and low accuracy (not saying they will all work, but would be good places to start).
#
# Since the model contains such unbalanced data we could:
# - Try using class weights for the Department Category or resampling to minimize the impact of the unbalanced data.
# - Add training data, change the percentage of training/testing data, or reduce the number of eophs.
# - Improve the training data by identifying alternative features, or perhaps scaling the current features.
#
# Use another metric instead of accuracy to better understand the model's performance and where potential issues lie.
#
# Fine tune the model: use hyperparameters (i.e. Keras tuner) to optimize the number of neurons, the number of hidden layers, the appropriate activation function, and the number of epochs.

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1.
# 2.
# 3.
